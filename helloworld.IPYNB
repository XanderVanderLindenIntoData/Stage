# %%
import sklearn
from litgpt import LLM

llm = LLM.load("microsoft/phi-2")
text = llm.generate("Fix the spelling: Every fall, the familly goes to the mountains.")
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\litgpt\utils.py:625, in auto_download_checkpoint(model_name, access_token, ignore_tokenizer_files)
#     624 try:
# --> 625     check_valid_checkpoint_dir(checkpoint_dir, verbose=False, raise_error=True, ignore_tokenizer_files=ignore_tokenizer_files)
#     626 except FileNotFoundError as e:
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\litgpt\utils.py:131, in check_valid_checkpoint_dir(checkpoint_dir, model_filename, verbose, raise_error, ignore_tokenizer_files)
#     130 if raise_error:
# --> 131     raise FileNotFoundError(f"checkpoint_dir {str(checkpoint_dir.absolute())!r}{problem}.")
#     132 else:
#
# FileNotFoundError: checkpoint_dir 'c:\\Users\\Xander\\IntoData\\IntoDataStage\\Stage\\microsoft\\phi-2' is not a checkpoint directory.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:426, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     425 try:
# --> 426     hf_transfer.download(
#     427         url=url,
#     428         filename=temp_file.name,
#     429         max_files=constants.HF_TRANSFER_CONCURRENCY,
#     430         chunk_size=constants.DOWNLOAD_CHUNK_SIZE,
#     431         headers=headers,
#     432         parallel_failures=3,
#     433         max_retries=5,
#     434         **({"callback": progress.update} if supports_callback else {}),
#     435     )
#     436 except Exception as e:
#
# Exception: Error while removing corrupted file: The process cannot access the file because it is being used by another process. (os error 32)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:437, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     436 except Exception as e:
# --> 437     raise RuntimeError(
#     438         "An error occurred while downloading using `hf_transfer`. Consider"
#     439         " disabling HF_HUB_ENABLE_HF_TRANSFER for better error handling."
#     440     ) from e
#     441 if not supports_callback:
#
# RuntimeError: An error occurred while downloading using `hf_transfer`. Consider disabling HF_HUB_ENABLE_HF_TRANSFER for better error handling.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import sklearn
#       2 from litgpt import LLM
# ----> 4 llm = LLM.load("microsoft/phi-2")
#       5 text = llm.generate("Fix the spelling: Every fall, the familly goes to the mountains.")
#       6 print(text)
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\litgpt\api.py:180, in LLM.load(cls, model, init, tokenizer_dir, access_token, distribute)
#     177 allowed_init = {"pretrained", "random"}
#     179 if init == "pretrained":
# --> 180     checkpoint_dir = auto_download_checkpoint(model_name=model, access_token=access_token, ignore_tokenizer_files=tokenizer_dir is not None)
#     181     config = Config.from_file(checkpoint_dir / "model_config.yaml")
#     183 elif init == "random":
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\litgpt\utils.py:631, in auto_download_checkpoint(model_name, access_token, ignore_tokenizer_files)
#     628     access_token = os.getenv("HF_TOKEN")
#     630 if checkpoint_dir.parts[0] != "checkpoints" and not checkpoint_dir.is_absolute():
# --> 631     download_from_hub(repo_id=str(model_name), access_token=access_token)
#     632     checkpoint_dir = Path("checkpoints") / checkpoint_dir
#     633 else:
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\litgpt\scripts\download.py:87, in download_from_hub(repo_id, access_token, tokenizer_only, convert_checkpoint, dtype, checkpoint_dir, model_name)
#      85 directory = checkpoint_dir / repo_id
#      86 with gated_repo_catcher(repo_id, access_token):
# ---> 87     snapshot_download(
#      88         repo_id,
#      89         local_dir=directory,
#      90         allow_patterns=download_files,
#      91         token=access_token,
#      92     )
#      94 constants.HF_HUB_ENABLE_HF_TRANSFER = previous
#      95 download.HF_HUB_ENABLE_HF_TRANSFER = previous
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\_snapshot_download.py:294, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     290 if constants.HF_HUB_ENABLE_HF_TRANSFER:
#     291     # when using hf_transfer we don't want extra parallelism
#     292     # from the one hf_transfer provides
#     293     for file in filtered_repo_files:
# --> 294         _inner_hf_hub_download(file)
#     295 else:
#     296     thread_map(
#     297         _inner_hf_hub_download,
#     298         filtered_repo_files,
#    (...)
#     302         tqdm_class=tqdm_class or hf_tqdm,
#     303     )
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\_snapshot_download.py:270, in snapshot_download.<locals>._inner_hf_hub_download(repo_file)
#     269 def _inner_hf_hub_download(repo_file: str):
# --> 270     return hf_hub_download(
#     271         repo_id,
#     272         filename=repo_file,
#     273         repo_type=repo_type,
#     274         revision=commit_hash,
#     275         endpoint=endpoint,
#     276         cache_dir=cache_dir,
#     277         local_dir=local_dir,
#     278         local_dir_use_symlinks=local_dir_use_symlinks,
#     279         library_name=library_name,
#     280         library_version=library_version,
#     281         user_agent=user_agent,
#     282         proxies=proxies,
#     283         etag_timeout=etag_timeout,
#     284         resume_download=resume_download,
#     285         force_download=force_download,
#     286         token=token,
#     287         headers=headers,
#     288     )
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:840, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     831     if local_dir_use_symlinks != "auto":
#     832         warnings.warn(
#     833             "`local_dir_use_symlinks` parameter is deprecated and will be ignored. "
#     834             "The process to download files to a local folder has been updated and do "
#    (...)
#     837             "For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder."
#     838         )
# --> 840     return _hf_hub_download_to_local_dir(
#     841         # Destination
#     842         local_dir=local_dir,
#     843         # File info
#     844         repo_id=repo_id,
#     845         repo_type=repo_type,
#     846         filename=filename,
#     847         revision=revision,
#     848         # HTTP info
#     849         endpoint=endpoint,
#     850         etag_timeout=etag_timeout,
#     851         headers=hf_headers,
#     852         proxies=proxies,
#     853         token=token,
#     854         # Additional options
#     855         cache_dir=cache_dir,
#     856         force_download=force_download,
#     857         local_files_only=local_files_only,
#     858     )
#     859 else:
#     860     return _hf_hub_download_to_cache_dir(
#     861         # Destination
#     862         cache_dir=cache_dir,
#    (...)
#     876         force_download=force_download,
#     877     )
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1136, in _hf_hub_download_to_local_dir(local_dir, repo_id, repo_type, filename, revision, endpoint, etag_timeout, headers, proxies, token, cache_dir, force_download, local_files_only)
#    1134 with WeakFileLock(paths.lock_path):
#    1135     paths.file_path.unlink(missing_ok=True)  # delete outdated file first
# -> 1136     _download_to_tmp_and_move(
#    1137         incomplete_path=paths.incomplete_path(etag),
#    1138         destination_path=paths.file_path,
#    1139         url_to_download=url_to_download,
#    1140         proxies=proxies,
#    1141         headers=headers,
#    1142         expected_size=expected_size,
#    1143         filename=filename,
#    1144         force_download=force_download,
#    1145     )
#    1147 write_download_metadata(local_dir=local_dir, filename=filename, commit_hash=commit_hash, etag=etag)
#    1148 return str(paths.file_path)
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1543, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1540         _check_disk_space(expected_size, incomplete_path.parent)
#    1541         _check_disk_space(expected_size, destination_path.parent)
# -> 1543     http_get(
#    1544         url_to_download,
#    1545         f,
#    1546         proxies=proxies,
#    1547         resume_size=resume_size,
#    1548         headers=headers,
#    1549         expected_size=expected_size,
#    1550     )
#    1552 logger.info(f"Download complete. Moving file to {destination_path}")
#    1553 _chmod_and_move(incomplete_path, destination_path)
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:416, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     398 # Stream file to buffer
#     399 progress_cm: tqdm = (
#     400     tqdm(  # type: ignore[assignment]
#     401         unit="B",
#    (...)
#     413     #   case, the progress bar is not closed when exiting the context manager.
#     414 )
# --> 416 with progress_cm as progress:
#     417     if hf_transfer and total is not None and total > 5 * constants.DOWNLOAD_CHUNK_SIZE:
#     418         supports_callback = "callback" in inspect.signature(hf_transfer.download).parameters
#
# File c:\Users\Xander\AppData\Local\Programs\Python\Python312\Lib\site-packages\tqdm\std.py:1138, in tqdm.__exit__(self, exc_type, exc_value, traceback)
#    1135 def __enter__(self):
#    1136     return self
# -> 1138 def __exit__(self, exc_type, exc_value, traceback):
#    1139     try:
#    1140         self.close()
#
# KeyboardInterrupt:
